# %% [markdown]
# # Ejercicio. Considere el siguiente tablero

# %%
import matplotlib.pyplot as plt

# Datos para el gráfico de pastel
sizes = [25, 25, 25, 25]  # Porcentajes de cada sección
colors = ['red', 'black', 'green', '#87CEEB']  # Colores de cada sección (rosa claro, plata, verde claro, azul claro)
labels = ['Cuadrante 1', 'Cuadrante 2', 'Cuadrante 3', 'Cuadrante 4']  # Etiquetas para cada sección

# Crea el gráfico de pastel
plt.figure(figsize=(6,6))
plt.pie(sizes, colors=colors)

# Ajusta el aspecto para que sea un círculo
plt.axis('equal')

# Muestra el gráfico
plt.show()

# %% [markdown]
# Lanzamos dos monedas y avanzamos en sentido horario, el número de caras que aparezcan. Si repetimos el procedimiento
# ## ¿Son todos los sectores igual de probables cuando pase mucho tiempo?

# %% [markdown]
# ## Analíticamente

# %% [markdown]
# Consideremos la cadena de Markov con espacio de estados $S = \{N,R,A,V\}$, en donde: **N:= Negro**, **R:= Rojo**, **A:= Azul** y **V:= Verde**.
#
# Además, consideremos que menciona que avanzaremos en sentido horario la cantidad de caras que caigan, es decir, puede ocurrir los siguientes casos:
# $\{XX,XC,CX,XX\}$, entonces, las prbabilidades quedarian como:
#
# $0 \text{ pasos } \leftarrow \frac {1}{4}$
#
# $1 \text{ pasos } \leftarrow \frac {1}{2}$
#
# $2 \text{ pasos } \leftarrow \frac {1}{4}$
#
# Así, la matriz de transición de la cadena de Markov quedaría como:
# \begin{equation*}
# P =
# \begin{bmatrix}
# \frac{1}{4} & \frac{1}{2} & \frac{1}{4} & 0 \\
# 0 & \frac{1}{4} & \frac{1}{2} & \frac{1}{4} \\
# \frac{1}{4} & 0 & \frac{1}{4} & \frac{1}{2} \\
# \frac{1}{2} & \frac{1}{4} & 0 & \frac{1}{4}
# \end{bmatrix}
# \end{equation*}
#
# Utilizando la propiedad de la **distribución estacionaria** para una cadena de Markov, es decir,
# \begin{equation*}
# \begin{aligned}
# \textbf{P} \pi =& \pi\\
# \begin{bmatrix}
# \frac{1}{4} & \frac{1}{2} & \frac{1}{4} & 0 \\
# 0 & \frac{1}{4} & \frac{1}{2} & \frac{1}{4} \\
# \frac{1}{4} & 0 & \frac{1}{4} & \frac{1}{2} \\
# \frac{1}{2} & \frac{1}{4} & 0 & \frac{1}{4}
# \end{bmatrix}  \times
# \begin{bmatrix}
# \pi_N \\
# \pi_R\\
# \pi_A\\
# \pi_V
# \end{bmatrix} &=
# \begin{bmatrix}
# \pi_N \\
# \pi_R\\
# \pi_A\\
# \pi_V
# \end{bmatrix}
# \\
# \end{aligned}
# \end{equation*}
# Además de esto, sabemos que se debe de satisfacer que todos los valores sean no negativos y además su suma sea igual a uno, es decir
# \begin{equation*}
# \pi_N + \pi_R + \pi_A + \pi_V = 1
# \end{equation*}
# Entonces, remplazamos esta condición con alguna ecuación del sistema de ecuaciones
#
#
#
#
# \begin{equation*}
# \begin{aligned}
# \begin{bmatrix}
# -\frac{3}{4} & \frac{1}{2} & \frac{1}{4} & 0 \\
# 0 & -\frac{3}{4} & \frac{1}{2} & \frac{1}{4} \\
# \frac{1}{4} & 0 & -\frac{3}{4} & \frac{1}{2} \\
# 1 & 1 & 1 & 1
# \end{bmatrix}  \times
# \begin{bmatrix}
# \pi_N \\
# \pi_R\\
# \pi_A\\
# \pi_V
# \end{bmatrix} &=
# \begin{bmatrix}
# 0\\
# 0\\
# 0\\
# 1
# \end{bmatrix}
# \\
# \end{aligned}
# \end{equation*}
#
# Resolviendo el sistema de ecuaciones, tenemos:
# \begin{equation*}
# \begin{aligned}
# \pi_N &= \frac{1}{4}\\
# \pi_R &= \frac{1}{4}\\
# \pi_A &= \frac{1}{4}\\
# \pi_V &= \frac{1}{4}
# \end{aligned}
# \end{equation*}
#
#
# ## Es decir, todos los sectores son igual de probables cuando pase mucho tiempo.

# %% [markdown]
# ## Simulación

# %%
import numpy as np
import random
import math
import matplotlib.pyplot as plt

# %%
def simulaciones_t(sim):
    import random
    
    sector = ['NEGRO','ROJO','AZUL','VERDE']
    z = random.choice(sector)
    moneda1 = ['C','X']
    moneda2 = ['C','X']
    
    n = 0
    r = 0
    a = 0
    v = 0
    veces = [n,r,a,v]
    #Negro
    for j in range(len(veces)):
        for i in range(1,sim+1):
            if (random.choice(moneda1) == 'X') and (random.choice(moneda2) == 'X'):
                veces[j]+=1
            elif (random.choice(moneda1) == 'C') and (random.choice(moneda2) == 'X') or (random.choice(moneda1) == 'X') and (random.choice(moneda2) == 'C'):
                if j<len(veces)-1:
                    veces[j+1]+=1
                else:
                    veces[j-3]+=1
            else:
                if j<len(veces)-2:
                    veces[j+2]+=1
                else:
                    veces[(j+1)-3]+=1
    #for k in range(len(veces)):
        #probabilidad = veces[k] / (sim * 4)
        #print("La probabilidad de llegar al sector", sector[k], "cuando pase mucho tiempo es:", probabilidad)
    proba = [v / (sim * 4) for v in veces]
    return proba

# %% [markdown]
# ## Es decir, todos los sectores son igual de probables cuando pase mucho tiempo.

# %%
def valor(repeticiones): #Esta función hara la simulación anterior muchas veces, es decir, hará "repeticiones" cantidad de veces
    PN = []
    PR = []
    PA = []
    PV = []
    for i in range(repeticiones):
        SM = simulaciones_t(10**4)
        PN.append(np.mean(SM[0])) 
        PR.append(np.mean(SM[1]))
        PA.append(np.mean(SM[2]))
        PV.append(np.mean(SM[3]))
    return PN, PR, PA, PV

# %%
N=100
simulacion = valor(N)

# %%
sector = ['NEGRO','ROJO','AZUL','VERDE']
for j in range(len(simulacion)):
    x = np.mean(simulacion[j])
    print("Proba de ",sector[j], "es: ",x)
# Out:
# Proba de  NEGRO es:  0.24969174999999996
# Proba de  ROJO es:  0.24979275
# Proba de  AZUL es:  0.250114
# Proba de  VERDE es:  0.25040150000000005

# %%
sector = ['NEGRO','ROJO','AZUL','VERDE']
for j in range(len(simulacion)):
    plt.hist(simulacion[j]) #Grafica las frecuencias de la aproximación al valor de la integral de las N simualciones con 750 experiementos cada una.
    plt.xlabel('iteraciones')
    plt.ylabel('Frecuencia')
    plt.title('Probabilidad que caiga '+ str(sector[j]))
    plt.show()

# %% [markdown]
# **PASO 9**. Calcule la media del área bajo la curva de la función y su desviación estándar.

# %%
#Negro
media_N = np.mean(simulacion[0]) #Calcula la media de esas N simulaciones
var_N = np.var(simulacion[0]) #Calcula la varianza de esas N simulaciones
desv_N = np.std(simulacion[0]) #Calcula la desvaicion de esas N simulaciones


#Rojo
media_R = np.mean(simulacion[1]) #Calcula la media de esas N simulaciones
var_R = np.var(simulacion[1]) #Calcula la varianza de esas N simulaciones
desv_R = np.std(simulacion[1]) #Calcula la desvaicion de esas N simulaciones



#Azul
media_A = np.mean(simulacion[2]) #Calcula la media de esas N simulaciones
var_A = np.var(simulacion[2]) #Calcula la varianza de esas N simulaciones
desv_A = np.std(simulacion[2]) #Calcula la desvaicion de esas N simulaciones



#Verde
media_V = np.mean(simulacion[3]) #Calcula la media de esas N simulaciones
var_V = np.var(simulacion[3]) #Calcula la varianza de esas N simulaciones
desv_V = np.std(simulacion[3]) #Calcula la desvaicion de esas N simulaciones

# %% [markdown]
# **PASO 10**. Halle el intervalo de confianza del valor de la integral con un nivel de confianza del $95 \%$.
# \begin{equation*}
# \overline{x}- Z_{\frac{\alpha}{2}}  \cdot \frac{S}{\sqrt{N}} < \mu < \overline{x}+ Z_{\frac{\alpha}{2}}  \cdot \frac{S}{\sqrt{N}}
# \end{equation*}

# %%
#Negro
from scipy.stats import norm #Importamos la libreria para poder obtener el valor de Z.
alpha = 1 - 0.95 #Alpha es igual a 1 - la confianza del intervalo
z_alpha_2 = norm.ppf(1-alpha / 2) #Mandamos a pedir el valor de Z para \alpha/2, sabemos que si es el 95% de confienza, Z esta cercano al 1.96.
l_inferior = media_N - z_alpha_2 * (desv_N / math.sqrt(N)) #Sacamos limite inferior por la formula
l_superior = media_N + z_alpha_2 * (desv_N / math.sqrt(N)) #Sacamos limite superior por la formula
print("Entonces: ", l_inferior, "< \u03BC Negro <", l_superior) #El intervalo en donde se encuentra el valor real a una confienza del 95%



#Rojo
from scipy.stats import norm #Importamos la libreria para poder obtener el valor de Z.
alpha = 1 - 0.95 #Alpha es igual a 1 - la confianza del intervalo
z_alpha_2 = norm.ppf(1-alpha / 2) #Mandamos a pedir el valor de Z para \alpha/2, sabemos que si es el 95% de confienza, Z esta cercano al 1.96.
l_inferior = media_R - z_alpha_2 * (desv_R / math.sqrt(N)) #Sacamos limite inferior por la formula
l_superior = media_R + z_alpha_2 * (desv_R / math.sqrt(N)) #Sacamos limite superior por la formula
print("Entonces: ", l_inferior, "< \u03BC Rojo <", l_superior) #El intervalo en donde se encuentra el valor real a una confienza del 95%


#Azul
from scipy.stats import norm #Importamos la libreria para poder obtener el valor de Z.
alpha = 1 - 0.95 #Alpha es igual a 1 - la confianza del intervalo
z_alpha_2 = norm.ppf(1-alpha / 2) #Mandamos a pedir el valor de Z para \alpha/2, sabemos que si es el 95% de confienza, Z esta cercano al 1.96.
l_inferior = media_A - z_alpha_2 * (desv_A / math.sqrt(N)) #Sacamos limite inferior por la formula
l_superior = media_A + z_alpha_2 * (desv_A / math.sqrt(N)) #Sacamos limite superior por la formula
print("Entonces: ", l_inferior, "< \u03BC Azul <", l_superior) #El intervalo en donde se encuentra el valor real a una confienza del 95%


#Verde
from scipy.stats import norm #Importamos la libreria para poder obtener el valor de Z.
alpha = 1 - 0.95 #Alpha es igual a 1 - la confianza del intervalo
z_alpha_2 = norm.ppf(1-alpha / 2) #Mandamos a pedir el valor de Z para \alpha/2, sabemos que si es el 95% de confienza, Z esta cercano al 1.96.
l_inferior = media_V - z_alpha_2 * (desv_V / math.sqrt(N)) #Sacamos limite inferior por la formula
l_superior = media_V + z_alpha_2 * (desv_V / math.sqrt(N)) #Sacamos limite superior por la formula
print("Entonces: ", l_inferior, "< \u03BC Verde <", l_superior) #El intervalo en donde se encuentra el valor real a una confienza del 95%
# Out:
# Entonces:  0.24931616299670883 < μ Negro < 0.2500673370032911
# Entonces:  0.24939401996915062 < μ Rojo < 0.2501914800308494
# Entonces:  0.2497371256813012 < μ Azul < 0.2504908743186988
# Entonces:  0.25009862307716224 < μ Verde < 0.25070437692283787
